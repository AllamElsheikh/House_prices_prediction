# %% [markdown]
# # **Exploratory Data Analysis (EDA) and Multivariate Analysis**
# This notebook performs **Exploratory Data Analysis (EDA)** on a dataset to uncover patterns, relationships, and potential insights. We utilize **univariate and multivariate analysis** techniques to understand data distributions, correlations, and feature interactions. The key steps include:
#
#
#
# *   Univariate analysis to explore individual feature distributions.
#
# *   Multivariate analysis using correlation heatmaps and pairplots to identify relationships between variables.
#
# *   Visualizations with Seaborn and Matplotlib for better data understanding.
#
# By the end of this notebook, we will have a solid foundation for feature selection, predictive modeling, and further AI/ML applications.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/content/House_prices_prediction/analyze_')
from basic_data_inspection  import DataTypeTech ,MathDescribtionTech  ,DataInspector

sys.path.append('/content/House_prices_prediction/analyze_/missing_values_analysis.py')
from missing_values_analysis import MissingValuesAnalysis

sys.path.append('/content/House_prices_prediction/analyze_/univariate_analysis.py')
from univariate_analysis import NumericalUnivariateAnalysisTech , CategoricalUnivariateAnalysisTech

sys.path.append('/content/House_prices_prediction/analyze_/bivariate_analysis.py')
from bivariate_analysis import NumericalVsNumUnivariateAnalysisTech , CategoricalVsNumUnivariateAnalysisTech

sys.path.append('/content/House_prices_prediction/analyze_/mulitvariate_analysis.py')
from mulitvariate_analysis import SimpleMultivariateAnalysis

# %%
df_path = "/content/House_prices_prediction/extracted_data/AmesHousing.csv"
df = pd.read_csv(df_path)

# %%
# 1 _ basic data inspections

#1.1 _ data type inspections
df_inspect = DataInspector(DataTypeTech())
df_inspect.execute_inspection(df)
# Out:
# ### Data Types and Non-null Counts ###
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
#1.2 _ statisticaal describtion inspection
df_inspect.set_strategy(MathDescribtionTech())
df_inspect.execute_inspection(df)
# Out:
# ### Summary Statistics (Numerical Features) ###
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
#2_ missing values identifiying and visualization
missing_analyzer = MissingValuesAnalysis()
missing_analyzer.analyze(df)
# Out:
# ### Missing Values Analysis ###
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
#3_1 univariate analysis for numberical features
univar_analyzer = NumericalUnivariateAnalysisTech()
univar_analyzer.analysis(df , "SalePrice")
# Out:
# Plot saved at: /content/plots/SalePrice_distribution.png

# %%
#3.2 _ univariate analysis for non-numberical features
univar_analyzer = CategoricalUnivariateAnalysisTech()
univar_analyzer.analysis(df , "Neighborhood")
# Out:
# Plot saved at: /content/plots/cat_Neighborhood_distribution.png

# %%
#4.1 _ bivariate analysis for numberical features
bivar_analyzer = NumericalVsNumUnivariateAnalysisTech()
bivar_analyzer.analysis(df, 'Gr Liv Area', 'SalePrice')
# Out:
# Plot saved at: /content/plots/Gr Liv Area vs SalePrice_distribution.png

# %%
#4.2 _ Bivariate analysis for categorical VS numberical features
bivar_analyzer = CategoricalVsNumUnivariateAnalysisTech()
bivar_analyzer.analysis(df, 'Overall Qual', 'SalePrice')
# Out:
# Plot saved at: /content/plots/Overall Qual vs SalePrice_distribution.png

# %%
#5 _ pair ploting and correlation plotting .
mulit_var_analyzer = SimpleMultivariateAnalysis()
selected_features = df[['SalePrice', 'Gr Liv Area', 'Overall Qual', 'Total Bsmt SF', 'Year Built']]

mulit_var_analyzer.analysis(selected_features)
# Out:
# Plot saved at: /content/plots/correlation_plot.png
# Plot saved at: /content/plots/pairplot.png

# %% [markdown]
# ## Conclusion .
#
# In this notebook, we successfully conducted Exploratory **Data Analysis (EDA)**, gaining valuable insights into the dataset. Key takeaways include:
# *    ✔dentified missing values and handled them appropriately.
# *    ✔ Explored individual feature distributions through univariate analysis.
# *    ✔ Analyzed relationships between variables using multivariate techniques, including correlation heatmaps and pairplots.
# *    ✔ Used visualizations to enhance interpretability and decision-making.
#
# These findings will serve as a strong foundation for feature engineering, model building, and further AI-driven analytics. Next steps may include applying feature selection techniques, building predictive models, or deploying data-driven solutions. 🚀
